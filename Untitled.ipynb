# %%
import numpy as np
import tensorflow as tf
import keras
import pandas as pd
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense

# %%
learning_rate = 0.01
epochs = 1000
display_step = 50

# %%
X_data = np.array([3.3,4.4,5.5,6.71,6.93,4.168,9.779,6.182,7.59,2.167,
                         7.042,10.791,5.313,7.997,5.654,9.27,3.1])
y_data = np.array([1.7,2.76,2.09,3.19,1.694,1.573,3.366,2.596,2.53,1.221,
                         2.827,3.465,1.65,2.904,2.42,2.94,1.3])

n_samples = X.shape[0]

# %%
X_data = tf.convert_to_tensor(X_data)
y_data = tf.convert_to_tensor(y_data)

# set model weights
W = tf.Variable(np.random.randn(), name = "weight", dtype="float64")
b = tf.Variable(np.random.randn(), name = "bias", dtype="float64")

# %%
X_data = tf.Variable([3.3,4.4,5.5,6.71,6.93,4.168,9.779,6.182,7.59,2.167,
                         7.042,10.791,5.313,7.997,5.654,9.27,3.1])
y_data = tf.Variable([1.7,2.76,2.09,3.19,1.694,1.573,3.366,2.596,2.53,1.221,
                         2.827,3.465,1.65,2.904,2.42,2.94,1.3])


# set model weights
W = tf.Variable(np.random.randn(), name = "weight", dtype="float32")
b = tf.Variable(np.random.randn(), name = "bias", dtype="float32")

# %%
# construct a linear model
y = tf.add(tf.multiply(W,X_data),b)

# %%
# mean squared error
#loss = tf.reduce_mean(tf.square(y-y_data))
loss = tf.reduce_sum(tf.pow(y-y_data, 2))/(2*17)
# optimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate)

# training method
train = optimizer.minimize(loss)

# initialize the variable
init = tf.global_variables_initializer()

# %%
loss_values = []
train_data = []
with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(epochs):
        _, loss_val, a_val, b_val = sess.run([train, loss, X_data, y_data])
        loss_values.append(loss_val)
        if epoch % 50 ==0:
            print(epoch,loss_val, sess.run(W), sess.run(b), sess.run(y_data))
            train_data.append([a_val, b_val])
# Out:
# 0 17.934402 0.91058433 -0.39080063 [1.7013401 2.7615623 2.0928023 3.193086  1.6981351 1.5750822 3.3713427
#  2.5990293 2.5341508 1.2217504 2.8305547 3.4710627 1.6529175 2.908244
#  2.4227269 2.9452019 1.3014214]
# 50 0.15272614 0.42049482 -0.38593632 [1.6826011 2.7263649 2.091112  3.175198  1.7262862 1.571182  3.387868
#  2.5915022 2.5466502 1.2022641 2.827424  3.497753  1.6615291 2.9151793
#  2.4134874 2.967482  1.2916609]
# 100 0.13398747 0.41127953 -0.32015756 [1.6634942 2.6903849 2.086528  3.153898  1.7492703 1.5656434 3.3971024
#  2.5806794 2.5539296 1.1834376 2.8200874 3.5159118 1.6670663 2.9167233
#  2.401477  2.982724  1.2814056]
# 150 0.11807655 0.40292117 -0.2605358 [1.6460048 2.6563098 2.0825186 3.1334238 1.7715367 1.5610464 3.4053566
#  2.570465  2.5608516 1.1665066 2.813023  3.5325363 1.6728817 2.9179993
#  2.3902483 2.9969146 1.2725209]
# 200 0.10450851 0.39533636 -0.2064632 [1.6299818 2.6240008 2.0790198 3.1137311 1.7931094 1.5572863 3.4127288
# ...
